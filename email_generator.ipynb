# %%
import google.generativeai as genai

# Configure API key
genai.configure(api_key="AIzaSyBWD0zLkos2W4Qz_-MaAiK0nm5Xy1sfGDU")

# Load Gemini model
model = genai.GenerativeModel("gemini-3-pro-preview")

# Invoke the model
response = model.generate_content(
    "who is the first drone company in india "
)

print(response.text)
# Out:
# **ideaForge** is widely considered the first drone company in India.
#
# Here are the key details about their origin:
#
# *   **Founded:** 2007
# *   **Founders:** Ankit Mehta, Rahul Singh, and Ashish Bhat (alumni of IIT Bombay).
# *   **Significance:** They pioneered the indigenous drone industry in India. They gained early fame for developing the **NETRA UAV** in collaboration with the DRDO (Defence Research and Development Organisation).
# *   **Pop Culture Moment:** One of their early prototypes was famously featured in the 2009 Bollywood movie *3 Idiots*.
# *   **Current Status:** They remain a market leader in the Indian defense and civil drone sector and became a publicly listed company on the Indian stock exchanges in July 2023.

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://www.google.com/about/careers/applications/jobs/results/118540784596067014-senior-field-sales-representative-transportation-google-cloud-japanese")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

from chains import Chain

chain = Chain()
jobs = chain.extract_jobs(page_data)
type(jobs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 16
#       1 from langchain_core.prompts import PromptTemplate
#       3 prompt_extract = PromptTemplate.from_template(
#       4         """
#       5         ### SCRAPED TEXT FROM WEBSITE:
#    (...)     13         """
#      14 )
# ---> 16 from chains import Chain
#      18 chain = Chain()
#      19 jobs = chain.extract_jobs(page_data)
#
# ModuleNotFoundError: No module named 'chains'

# %%
from langchain_core.output_parsers import JsonOutputParser

def to_text(content):
    if isinstance(content, list):
        return "".join(
            block.get("text", "")
            for block in content
            if isinstance(block, dict)
        )
    return content

chain = Chain()
jobs = chain.extract_jobs(page_data)

print(type(jobs))      
print(jobs[0].keys())
# Out:
# Chain initialized
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 12
#       5         return "".join(
#       6             block.get("text", "")
#       7             for block in content
#       8             if isinstance(block, dict)
#       9         )
#      10     return content
# ---> 12 chain = Chain()
#      13 jobs = chain.extract_jobs(page_data)
#      15 print(type(jobs))
#
# Cell In[1], line 5, in Chain.__init__(self)
#       3 def __init__(self):
#       4     print("Chain initialized")
# ----> 5     from chains import Chain
#
# ModuleNotFoundError: No module named 'chains'

# %%
type(json_res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 type(json_res)
#
# NameError: name 'json_res' is not defined

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient(path="vectorstore")
collection = client.get_or_create_collection(name="portfolio")

if collection.count() == 0:
    for _, row in df.iterrows():
        collection.add(
            documents=[row["Techstack"]],          
            metadatas=[{"links": row["Links"]}],   
            ids=[str(uuid.uuid4())]
        )

# %%
job_item = job[0]   

query_text = ", ".join(job_item["skills"])

links = collection.query(
    query_texts=[query_text],
    n_results=2
).get("metadatas", [])

links
# Out:
# [[{'links': 'https://example.com/python-portfolio'},
#   {'links': 'https://example.com/ml-python-portfolio'}]]

# %%
job
# Out:
# [{'role': 'Administrative Business Partner, Finance',
#   'experience': 'Minimum: 3 years of administrative experience in a technology or international environment working on core administrative tasks (e.g., travel management, expense reports, calendar management, facilities coordination, etc.). Preferred: 6 years of administrative experience supporting executive-level management in a corporate environment, and managing small-scale projects and events from pre-planning to execution.',
#   'skills': ['Travel management',
#    'Expense reports',
#    'Calendar management',
#    'Facilities coordination',
#    'Event planning',
#    'Project management',
#    'Business judgment',
#    'Communication skills',
#    'Analytical skills',
#    'English proficiency'],
# ...

# %%
job[0]['skills']
# Out:
# ['Fluent Japanese',
#  'B2B Sales',
#  'Cloud Computing',
#  'IT Solutions',
#  'Infrastructure Software',
#  'Partner Management',
#  'Contract Negotiation',
#  'C-level Presentation',
#  'Account Strategy',
#  'Business Development',
#  'Sales Forecasting',
#  'Stakeholder Management']

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
       Hello,

I’m Mohan, a Business Development Executive at Dhruv.AI. We are an AI and drone technology company focused on seamlessly integrating artificial intelligence with autonomous drone systems to solve real-world industrial and enterprise challenges.

Based on the role you’re currently hiring for, it’s clear that advanced automation, intelligent data processing, and scalable technology solutions are central to your requirements. At Dhruv.AI, we specialize in building end-to-end AI-driven drone and software solutions that support process optimization, operational efficiency, and cost reduction across domains such as inspection, surveillance, analytics, and precision operations.

Our experience includes developing customized AI models, autonomous drone workflows, and integrated dashboards that help organizations improve decision-making, reduce manual effort, and scale operations reliably. We work closely with client teams to ensure our solutions align with both technical and business objectives.

To give you a better sense of our work, here are a few relevant projects from our portfolio that align closely with your needs:
{link_list}

I would be happy to explore how Dhruv.AI can support your team with tailored AI and drone solutions for this role. Let me know if you’d be open to a brief discussion.

Best regards,
Mohan
Business Development Executive
Dhruv.AI

        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 31
#       1 prompt_email = PromptTemplate.from_template(
#       2         """
#       3         ### JOB DESCRIPTION:
#    (...)     28         """
#      29         )
# ---> 31 chain_email = prompt_email | llm
#      32 res = chain_email.invoke({"job_description": str(job), "link_list": links})
#      33 print(res.content)
#
# NameError: name 'llm' is not defined
