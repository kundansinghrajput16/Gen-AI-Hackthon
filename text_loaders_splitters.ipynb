# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("nvda_news_1.txt")
loader.load()
# Out:
# [Document(metadata={'source': 'nvda_news_1.txt'}, page_content="The stock of NVIDIA Corp (NASDAQ:NVDA) experienced a daily loss of -3.56% and a 3-month gain of 32.35%. With an Earnings Per Share (EPS) (EPS) of $1.92, the question arises: is the stock significantly overvalued? This article aims to provide a detailed valuation analysis of NVIDIA, offering insights into its financial strength, profitability, growth, and more. We invite you to delve into this comprehensive analysis.\n\nCompany Overview\nWarning! GuruFocus has detected 10 Warning Signs with NVDA. Click here to check it out.\n\nNVDA 30-Year Financial Data\n\nThe intrinsic value of NVDA\n\n\nNVIDIA Corp (NASDAQ:NVDA) is a leading designer of discrete graphics processing units that enhance the experience on computing platforms. The firm's chips are widely used in various end markets, including PC gaming and data centers. In recent years, NVIDIA has broadened its focus from traditional PC graphics applications such as gaming 
# ...

# %%
type(loader)loader.file_path
# Out:
# langchain_community.document_loaders.text.TextLoader

# %%
loader.file_path
# Out:
# 'nvda_news_1.txt'

# %%
from langchain_community.document_loaders import CSVLoader

# %%
loader = CSVLoader(file_path="movies.csv")
data = loader.load()
data
# Out:
# [Document(metadata={'source': 'movies.csv', 'row': 0}, page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR'),
#  Document(metadata={'source': 'movies.csv', 'row': 1}, page_content='movie_id: 102\ntitle: Doctor Strange in the Multiverse of Madness\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 7\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 200\nrevenue: 954.8\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'movies.csv', 'row': 2}, page_content='movie_id: 103\ntitle: Thor: The Dark World\nindustry: Hollywood\nrelease_year: 2013\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 165\nrevenue: 644.8\nunit: Millions\ncurrency: USD'),
# ...

# %%
data[0]
# Out:
# Document(metadata={'source': 'movies.csv', 'row': 0}, page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR')

# %%
loader = CSVLoader(file_path="movies.csv", source_column="title")
data = loader.load()
data
# Out:
# [Document(metadata={'source': 'K.G.F: Chapter 2', 'row': 0}, page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR'),
#  Document(metadata={'source': 'Doctor Strange in the Multiverse of Madness', 'row': 1}, page_content='movie_id: 102\ntitle: Doctor Strange in the Multiverse of Madness\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 7\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 200\nrevenue: 954.8\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'Thor: The Dark World', 'row': 2}, page_content='movie_id: 103\ntitle: Thor: The Dark World\nindustry: Hollywood\nrelease_year: 2013\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 165\nrevenue: 644.8\nunit: Millions\ncurrency: USD'),
# ...

# %%
data[0].page_content
# Out:
# 'movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR'

# %%
data[0].metadata
# Out:
# {'source': 'K.G.F: Chapter 2', 'row': 0}

# %%
# %pip install unstructured python-magic langchain-community
# Out:
# ...
#   Using cached unstructured-0.18.21-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached lxml-6.0.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (3.6 kB)
# ...
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 1.3 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached regex-2025.11.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# ...
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 4.0 MB/s eta 0:00:004.8 MB/s eta 0:00:01
# Using cached python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# ...

# %%
from langchain_community.document_loaders import UnstructuredURLLoader

urls = [
    "https://www.downtoearth.org.in/agriculture/agricultural-drones-are-taking-off-globally-saving-farmers-time-and-money",
    "https://agrotechindia.co.in/agriculture-drone/"
]


loader = UnstructuredURLLoader(urls=urls)

# %%
data = loader.load()
len(data)
# Out:
# 1

# %%
data[0].page_content[0:100]
# Out:
# 'डाउन टू अर्थ\n\nPrint Edition\n\ndowntoearth\n\nSubscribe\n\nHealth\n\nAgriculture\n\nWater\n\nWaste\n\nClimate\n\nAir'

# %%
data[0].metadata
# Out:
# {'source': 'https://www.downtoearth.org.in/agriculture/agricultural-drones-are-taking-off-globally-saving-farmers-time-and-money'}

# %%
text = '''There is a large capacity for growth in the area of agricultural drones. With technology constantly improving, imaging of the crops will need to improve as well. With the data that drones record from the crops the farmers are able to analyze their crops and 
make educated decisions on how to proceed given the accurate crop information. Software programs for analyzing and correcting crop production[8] have the potential to grow in this market. Farmers will fly a drone over their crops, accurately identify an issue in a specific
area, and take the necessary actions to correct the problem.[9] This gives the farmer time to focus on the overall task of production 
instead of spending time surveying their crops. Additional uses include keeping track of livestock, surveying fences, and monitoring for plant pathogens.[10]
Both the purchase and maintenance costs of modern drones make them too expensive for small farms in developing nations. 
Pilot programs in Tanzania are focusing on minimizing those costs, producing agricultural drones simple and rugged enough to be repaired locally.[11]
A research team from Washington State University has developed an automated drone system that deters pests like crows or European starlings from feeding on grapes and other crops. 
The birds could be scared off by the drone's noise, but researchers also could include distress calls and predatory bird noises.[12]'''

# %%
text[0:100]
# Out:
# 'There is a large capacity for growth in the area of agricultural drones. With technology constantly '

# %%
words = text.split(" ")
len(words)
# Out:
# 218

# %%
chunks = []

s = ""
for word in words:
    s += word + " "
    if len(s)>200:
        chunks.append(s)
        s = ""
        
chunks.append(s)

# %%
chunks[:2]
# Out:
# ['There is a large capacity for growth in the area of agricultural drones. With technology constantly improving, imaging of the crops will need to improve as well. With the data that drones record from the ',
#  'crops the farmers are able to analyze their crops and \nmake educated decisions on how to proceed given the accurate crop information. Software programs for analyzing and correcting crop production[8] have ']

# %%
from langchain_text_splitters import CharacterTextSplitter


splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size=200,
    chunk_overlap=0
)

# %%
chunks = splitter.split_text(text)
len(chunks)
# Out:
# Created a chunk of size 258, which is longer than the specified 200
# Created a chunk of size 273, which is longer than the specified 200
# 8

# %%
for chunk in chunks:
    print(len(chunk))
# Out:
# 257
# 273
# 133
# 157
# 119
# 149
# 179
# 132

# %%
text
# Out:
# "There is a large capacity for growth in the area of agricultural drones. With technology constantly improving, imaging of the crops will need to improve as well. With the data that drones record from the crops the farmers are able to analyze their crops and \nmake educated decisions on how to proceed given the accurate crop information. Software programs for analyzing and correcting crop production[8] have the potential to grow in this market. Farmers will fly a drone over their crops, accurately identify an issue in a specific\narea, and take the necessary actions to correct the problem.[9] This gives the farmer time to focus on the overall task of production \ninstead of spending time surveying their crops. Additional uses include keeping track of livestock, surveying fences, and monitoring for plant pathogens.[10]\nBoth the purchase and maintenance costs of modern drones make them too expensive for small farms in developing nations. \nPilot programs in Tanzania are focusing on mi
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

r_splitter = RecursiveCharacterTextSplitter(
    separators=["\n\n", "\n", " "],
    chunk_size=200,
    chunk_overlap=0,
    length_function=len
)

# %%
chunks = r_splitter.split_text(text)

for chunk in chunks:
    print(len(chunk))
# Out:
# 199
# 57
# 195
# 77
# 133
# 157
# 119
# 149
# 179
# 132

# %%
first_split = text.split("\n\n")[0]
first_split
# Out:
# "There is a large capacity for growth in the area of agricultural drones. With technology constantly improving, imaging of the crops will need to improve as well. With the data that drones record from the crops the farmers are able to analyze their crops and \nmake educated decisions on how to proceed given the accurate crop information. Software programs for analyzing and correcting crop production[8] have the potential to grow in this market. Farmers will fly a drone over their crops, accurately identify an issue in a specific\narea, and take the necessary actions to correct the problem.[9] This gives the farmer time to focus on the overall task of production \ninstead of spending time surveying their crops. Additional uses include keeping track of livestock, surveying fences, and monitoring for plant pathogens.[10]\nBoth the purchase and maintenance costs of modern drones make them too expensive for small farms in developing nations. \nPilot programs in Tanzania are focusing on mi
# ...

# %%
len(first_split)
# Out:
# 1410

# %%
second_split = first_split.split("\n")
second_split
# Out:
# ['There is a large capacity for growth in the area of agricultural drones. With technology constantly improving, imaging of the crops will need to improve as well. With the data that drones record from the crops the farmers are able to analyze their crops and ',
#  'make educated decisions on how to proceed given the accurate crop information. Software programs for analyzing and correcting crop production[8] have the potential to grow in this market. Farmers will fly a drone over their crops, accurately identify an issue in a specific',
#  'area, and take the necessary actions to correct the problem.[9] This gives the farmer time to focus on the overall task of production ',
#  'instead of spending time surveying their crops. Additional uses include keeping track of livestock, surveying fences, and monitoring for plant pathogens.[10]',
#  'Both the purchase and maintenance costs of modern drones make them too expensive for small farms in developing nations. ',
# ...

# %%
for split in second_split:
    print(len(split))
# Out:
# 258
# 273
# 134
# 157
# 120
# 149
# 180
# 132

# %%
second_split[2]
# Out:
# 'area, and take the necessary actions to correct the problem.[9] This gives the farmer time to focus on the overall task of production '
